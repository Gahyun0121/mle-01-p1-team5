# %%
import pandas as pd
import html
import os

alm = pd.read_json('../data/raw/alarm.json')
master = pd.read_csv('../data/country_master.csv')

print(alm.shape)
print(alm.columns.tolist())
print(alm.info())
# Out:
# (208, 9)
# ['국가명', '영문국가명', 'ISO 코드', '대륙 코드', '영문 대륙명', '한글 대륙명', '경보단계', '경보내용', '작성일']
# <class 'pandas.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가명     208 non-null    str
#  1   영문국가명   208 non-null    str
#  2   ISO 코드  208 non-null    str
#  3   대륙 코드   208 non-null    str
#  4   영문 대륙명  208 non-null    str
#  5   한글 대륙명  208 non-null    str
#  6   경보단계    208 non-null    int64
#  7   경보내용    208 non-null    str
#  8   작성일     0 non-null      float64
# dtypes: float64(1), int64(1), str(7)
# memory usage: 32.9 KB
# None

# %%
print(alm['경보내용'].str.contains(r'\s{2,}|\n').sum())
# Out:
# 1
